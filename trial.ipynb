# %%
import  google.generativeai as genai
from pypdf import PdfReader# type: ignore

# %%
genai.configure(api_key='AIzaSyDVRgAIYV0FBWpV0WvtUod6TrcxrDoAzEI')

# %%
# result = genai.embed_content(
#     model= "models/embedding-001",
#     content=page1,
#     task_type='retrieval_document',
#     title='Embedding of single string'
# )
# for v in result['embedding']:
#     print(str(v))[:50]

# %%
from bs4 import BeautifulSoup
import requests
url = "https://kathmandupost.com/sports/2024/05/01/nepal-announces-squad-for-icc-men-s-t20-world-cup"
response = requests.get(url)
html_content = response.text
html_content
# Out:
# '<!DOCTYPE html><html lang="en" ><head><meta charset="utf-8"><meta name="robots" content="" ><meta http-equiv="X-UA-Compatible" content="IE=edge"><meta http-equiv="cache-control" content="no-cache" /><meta name="viewport" content="width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=no"><title>Nepal bank on experience at T20 World Cup</title><meta name="description" content="Cricket Association of Nepal announces a 15-member squad adding Kamal Singh Airee and Sagar Dhakal. Binod Bhandari, Aarif Sheikh, Bibek Yadav, Lokesh Bam and Aakash Chand have been left out."><meta name="keyword" content="Nepal,will,begin,the,tournament,with,a,match,against,the,Netherlands,on,June,4."><meta name="language" content="English"><meta name="revisit-after" content="1 day"><meta property="og:image" content="https://assets-cdn.kathmandupost.com/uploads/source/news/2024/sports/nepal-1714612274.jpg" /><meta property="og:title" content="Nepal bank on experience at T20 World Cup" /><meta p
# ...

# %%
soup = BeautifulSoup(html_content,'html.parser')
# response = str(soup.find('div',class_='page-detail--content clearfix"'))
with open ('file1.txt','w' )as file:
    file.write(html_content)

# %%
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords
lemmatizer = WordNetLemmatizer()

# %%
import re 
def cleandata(text:str):
    '''Removes html tag and unnecessary text'''
    clean = re.compile('<.*?>')
    text = re.sub(clean,'',text)
    text = re.sub('[^a-zA-Z]',' ',text)
    text = text.lower()
    text = text.split()
    text = [lemmatizer.lemmatize(word)for word in text if not word in stopwords.words('english')]
    text = ' '.join(text)
    return text

# %%
# def separate_line(text:str):
#     lines = text.split('\n')
#     for line in lines:
#         print(line.strip() + '\n')

# %% [markdown]
# clean_text = cleandata()

# %%
clean_text = cleandata(html_content)
print(type(clean_text))
with open('file.txt','w') as file:
    file.write(clean_text)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[244], line 1
# ----> 1 clean_text = cleandata(html_content)
#       2 print(type(clean_text))
#       3 with open('file.txt','w') as file:
#
# Cell In[243], line 8, in cleandata(text)
#       6 text = re.sub('[^a-zA-Z]',' ',text)
#       7 text = text.lower()
# ----> 8 text = text.split('')
#       9 text = [lemmatizer.lemmatize(word)for word in text if not word in stopwords.words('english')]
#      10 text = ' '.join(text)
#
# ValueError: empty separator

# %%
from langchain_text_splitters import CharacterTextSplitter

text_splitter = CharacterTextSplitter(
    separator="",
    chunk_size=200,
    chunk_overlap=50,
)

# %%
texts = text_splitter.create_documents([clean_text])
texts
# Out:
# [Document(page_content='nepal bank on experience at t   world cupimg lazy  background rgba                 img lazy  background        ui menu   width     px    lazy content url  https   jcss cdn kathmandupost com assets images lazy png      start of lane block   header ads   sponsor header  background  f f f  margin    border bottom solid  px  efefef  position  relative  z index     ads block   background  fff    padding  rem   ads block img  max width          ads block h   margin    color   efefef  font size    rem   close btn  position  absolute right   px  top   px  width    px  height    px  z index      ui menu  width  auto    close btn cursor  pointer    end of lane block     roadblock    roadblock ad  position  fixed text align  center top    height       width       z index    min height     px   roadblock ad  wrap  display   webkit flex display   ms flexbox display  flex  webkit align items  center align items  center  webkit justify content  center justify content  center
# ...

# %%
len(texts)
# Out:
# 1

# %%
len(text_splitter.split_text(clean_text))
# Out:
# 1

# %%
len(text_splitter.split_text(clean_text))
# Out:
# 1
